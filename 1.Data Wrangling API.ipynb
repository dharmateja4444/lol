# %% [markdown]
# This Juypter Notebooked titled 'Exploring_Riot_API' isn’t endorsed by Riot Games and doesn’t reflect the views or opinions of Riot Games
# or anyone officially involved in producing or managing League of Legends. League of Legends and Riot Games are
# trademarks or registered trademarks of Riot Games, Inc. League of Legends © Riot Games, Inc.

# %% [markdown]
# # Data Wrangling and Cleaning

# %%
# %matplotlib inline
import pandas as pd
import requests
import time
import re
import pickle
import os
os.chdir(r'C:\Users\shukl\Desktop\APR\Infi\2\Predicting Matches Esports\Final')

# %%
#CSS to make default files look more readable
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# ## Obtaining Data from API

# %%
#ENTER API KEY HERE as string
#go to https://developer.riotgames.com/ to obtain API KEY

#TEMP KEY
api_key = 'RGAPI-90353f8a-275a-43d5-be43-210fcdb41280'

# %%
def get_acct_id(summoner_name, region, key):
    """
    Returns the encrypted summonerID for a players in game summoner name.
    
    summoner_name: string, in game summoner name
    region: string
    key: string
    """
    url = 'https://' + region +'.api.riotgames.com/lol/summoner/v4/summoners/' +\
          'by-name/' + summoner_name + '?api_key=' + key
    response = requests.get(url)
    
    if response.status_code == 200:
        print('App Rate Limit ' + response.headers['X-App-Rate-Limit'])
        print('App Rate Limit Count ' + response.headers['X-App-Rate-Limit-Count'])
        print(response.status_code)
        json_data = response.json()
        return json_data['accountId']
    #429 response means we hit the API rate limit 
    elif response.status_code == 429:
        print(response.status_code)
        print('Hit rate limit...Sleeping...')
        time.sleep(121)
        response = requests.get(url)
        json_data = response.json()
        return json_data['accountId']
    else:
        print(response.status_code)
        print('failed to get account id')
        return None

# %%
def get_match_history(acct_id, region, game_type, season,\
                      beg_ind, key):
    """
    returns past 100 match history as json
    use game_type '420' for 5v5 ranked
    season '11' for latest season
    """
    url = 'https://' + region + '.api.riotgames.com/lol/match/v4/matchlists/' +\
          'by-account/' + acct_id +'?queue=' + game_type + '&season=' + season +\
          '&beginIndex=' + str(beg_ind) + '&api_key=' + key
        
    response = requests.get(url)

    if response.status_code == 200:
        print('App Rate Limit ' + response.headers['X-App-Rate-Limit'])
        print('App Rate Limit Count ' + response.headers['X-App-Rate-Limit-Count'])
        print(response.status_code)
        json_data = response.json()
        return json_data
    #429 response means we hit the API rate limit 
    elif response.status_code == 429:
        print(response.status_code)
        print('Hit rate limit...Sleeping...')
        time.sleep(121)
        response = requests.get(url)
        json_data = response.json()
        return json_data
    else:
        print(response.status_code)
        return None

# %%
def get_match_history_int(acct_id, region, game_type, season, key, begin):
    """
    returns specified interval match history as json
    use game_type '420' for 5v5 ranked
    season '11' for latest season
    """
    url = 'https://' + region + '.api.riotgames.com/lol/match/v4/matchlists/' +\
          'by-account/' + acct_id +'?queue=' + game_type + '&season=' + season +\
          '&beginTime=' + str(begin) + '&api_key=' + key
    response = requests.get(url)
    
    if response.status_code == 200:
        print('App Rate Limit ' + response.headers['X-App-Rate-Limit'])
        print('App Rate Limit Count ' + response.headers['X-App-Rate-Limit-Count'])
        print(response.status_code)
        json_data = response.json()
        return json_data
    #429 response means we hit the API rate limit 
    elif response.status_code == 429:
        print(response.status_code)
        print('Hit rate limit...Sleeping...')
        time.sleep(121)
        response = requests.get(url)
        json_data = response.json()
        return json_data
    else:
        print(response.status_code)
        return None

# %%
def get_match_stats(match_id, region, key):
    """
    returns json of match stats based on match id
    """
    url = 'https://' + region +'.api.riotgames.com/lol/match/v4/matches/' +\
           str(match_id) + '?api_key=' + key
    response = requests.get(url)
    
    if response.status_code == 200:
        print('App Rate Limit ' + response.headers['X-App-Rate-Limit'])
        print('App Rate Limit Count ' + response.headers['X-App-Rate-Limit-Count'])
        print(response.status_code)
        json_data = response.json()
        return json_data
    #429 response means we hit the API rate limit 
    elif response.status_code == 429:
        print(response.status_code)
        print('Hit rate limit...Sleeping...')
        time.sleep(121)
        response = requests.get(url)
        json_data = response.json()
        return json_data
    else:
        print(response.status_code)
        print('No game data returned')
        return None

# %%
x = get_match_stats(2932547603, 'na1', api_key)
# Out:
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200

# %% [markdown]
# ## Cleaning the Data

# %%
#Champion Information
champion_data_url = 'http://ddragon.leagueoflegends.com/cdn/8.24.1/data/en_US/champion.json'
champ_response = requests.get(champion_data_url)
champ_json = champ_response.json()

# %%
#Champ list
champ_list = []
for champ in champ_json['data']:
    champ_list.append(champ)

# %%
#Champ type
champ_type = {}

for champ in champ_list:
    champ_type[champ] = champ_json['data'][champ]['tags']

# %%
#Create dict to map champion ids to champ names
#will use to clean data later
champ_dict = {}

for champ in champ_list:
    champ_dict[int(champ_json['data'][champ]['key'])] = champ

# %%
#Item Information
item_data_url = 'http://ddragon.leagueoflegends.com/cdn/8.24.1/data/en_US/item.json'
item_response = requests.get(item_data_url)
#print(item_response.status_code)
item_json = item_response.json()

# %%
#Access Item: item_json['data'][ITEM ID]['name']
item_json['data']['1001']['name']

#Item list
item_list = []
for item in item_json['data']:
    item_list.append(item)

# %%
#create a dict of item ids to map to item name for cleaning data
#Some of the item names were missing, went to api chat to find
item_dict = {}

for item in item_list:
    item_dict[int(item)] = item_json['data'][item]['name']

item_dict[0] = None

# %%
#Summoner Spell Info
sumspell_data_url = 'http://ddragon.leagueoflegends.com/cdn/8.24.1/data/en_US/summoner.json'
sumspell_response = requests.get(sumspell_data_url)
sumspell_json = sumspell_response.json()

# %%
#Access the sumspell ID num sumspell_json['data'][SUMSPELLNAME]['key']
#sumspell_json['data']['SummonerFlash']['key']

sumspell_list = []

for sumspell in sumspell_json['data']:
    sumspell_list.append(sumspell)

# %%
#create dict mapping of summoner spell id to name
sumspell_dict = {}
for spell in sumspell_list:
    sumspell_dict[int(sumspell_json['data'][spell]['key'])] = spell

#replace name of 'SummonerDot' to 'SummonerIgnite' like in game
sumspell_dict[14] = 'SummonerIgnite'

# %% [markdown]
# ## Building a Master Data Frame

# %%
#Lists of player names in first set
#Players are high tier ranked players from which we will draw match data from
players1 = ['scarra', 'gosu', 'trick2g' 'hashinshin', 'loltyler1', 'imaqtpie',
             'nightblue3', 'wingsofdeath', 'chapanya', 'shiphtur', 'doublelift',
            'voyboy', 'yassuo', 'gripex90','aphromoo', 'pokimane', 'dyrus', 'TF Blade',
           'pants are dragon', 'lourlo', 'allorim', 'Boxbôx', 'Per Se Bambi', 'horseie', 'Zile',
          'Nicolaj Jensen', 'pokeball', 'valkrin', 'hate', 'likeamaws', 'twinge',
          'sakurafloret', 'Chad jungle', 'mintcola', 'blobheart', 'joonroot', 'dominatelane',
           'vegeta', 'omnidk', 'dr beat', 'voki', 'kaipop', 'oogie', 'sophist sage',
           'takeji', 'zutter', 'haseeb', 'delyze', 'kicking', 'xiao ming',
           'SKT T1 Madlife', 'abibibi', 'Papá Chau', 'data88', 'wildtomgg',
           'bronson', 'd1 police', 'mercury','a noob draven', 'yao 17', 'xuegao',
           'treh', 'cdew', 'fakego', 'feng6', 'heisendong', 'pytrigon', 'billbobbilly', 'techxiii',
            'cao cao n1', 'honi', 'oddi3', 'adrian riv3n', 'xj11',
            'yu sang', 'meteos', 'ffwii', 'starwhale', 'iwdominatelol',
            'saskio', 'froogie', 'mancloud2', 'yoshi', 'haebaragi',
            'stuntopolis', 'wonhae', 'nopause', 'the holy slurp',
            '100T Bangg', '100t freeze', 'taproot86', 'bloodwater', 'catria', 'trinn',
            'nasfinest', 'im avi', 'liquid matt', 'dmytro', 'omizu', 'huhi',
            'TL cain', 'waynedwops', 'busioc', 'chaosrain', 'free papachau',
            'chris', '5fire', 'shiba inu', 'tsm bjergsen', '100t fragas', 'c9 sneaky',
           'thorn', 'deftsuo', 'adc abuser', 'dellzor', 'yisus', 'nebula', 'xin xin',
            'zoebestgurl', 'canadaad', 'rawvision', 'll stylish', 'oldhome', 'link',
            'rainbowboom', 'raigarak', 'thiengar', 'skeggsy', 'kyroo1', 'frosfroes',
            'wolfer', 'seouless', 'don tito', 'seanic', 'daddyio', 'aeriya',
            'quantum0002', 'ordinn', 'roja', 'boom u dead', 'rain lover',
            'jimmytheslayer', 'ikingvex', 'sun prince', 'morningst4r', 'zatsmod',
            'dragoonsmash', 'little mix', 'jim j poggers', 'll justice', 'shupian',
            'fwii', 'zaion', 'cile', 'gate', 'aesthetic player', 'duoqueen1',
            'urelectric', 'bigfatlp']

# %%
#Define function to get match history 
def get_many_matches(acct_names, key, file_name, add_on=False):
    '''
    Returns a list of match ids
    
    >>> l = [1,2,3,4]
    >>> with open("test.txt", "wb") as fp:   #Pickling
    ...   pickle.dump(l, fp)
    ... 
    >>> with open("test.txt", "rb") as fp:   # Unpickling
    ...   b = pickle.load(fp)
    ... 
    >>> b
    [1, 2, 3, 4]
    
    add_on = True -> add game ids to the specified pickled file
    add_on = False (default) -> create new pickled file of game ids
    '''
    #store matches in the list and keep count of api calls
    match_list = []
    bad_player_ids = []
    calls = 0
    
    #if the api is called 100 times, then sleep for 2 mins
    for player in acct_names:
        if calls == 100:
            print("API calls at 100, sleeping for 2 mins...")
            time.sleep(121)
            calls = 0
            
        acct_id = get_acct_id(player, 'na1', key)
        calls += 1
        
        if calls == 100:
            print("API calls at 100, sleeping for 2 mins...")
            time.sleep(121)
            calls = 0
        
        #Can sometimes return bad game data and return None
        #Handle the TypeError exception
        try:    
            beg_ind = 0
            data = get_match_history(acct_id, 'na1', '420', '11',\
                                     beg_ind, key)['matches']
            calls += 1
        except TypeError:
            #log current play and Skip current player and move on to the next
            bad_player_ids.append(player)
            continue
    
        while data != []:
            if calls == 100:
                print("API calls at 100, sleeping for 2 mins...")
                time.sleep(121)
                calls = 0
            
            data = get_match_history(acct_id, 'na1', '420', '11',\
                                     beg_ind, key)['matches']
            calls += 1
            
            for game in data:
                if game['gameId'] not in match_list:
                    match_list.append(game['gameId'])
            beg_ind += 100
            
    
    #store list using pickle for an existing file in 
    #the PlayerMatches directory
    if add_on == True:
        with open('PlayerMatches\\'+ file_name, 'rb') as file:
            old_list = pickle.load(file)
            old_list = list(set(old_list + match_list))
        with open('PlayerMatches\\'+ file_name, 'wb') as file:
            pickle.dump(old_list, file)
    
    #store list in a new file using pickle
    elif add_on == False:
        with open('PlayerMatches\\'+ file_name, 'wb') as file:
            pickle.dump(match_list, file)
    
    #print out player names for which we could not get match ids for
    if len(bad_player_ids) != 0:
        print('Could not return match ids for player: ' + str(bad_player_ids))

# %%
def create_row(json_data):
    #create all columns for dataframe
    row_contents = {}
    row_contents['game_id'] = json_data.get('gameId', 'unknown')
    row_contents['game_length_mins'] = json_data.get('gameDuration', 'unknown')
    add_player_name(row_contents, json_data)
    add_champ_pick(row_contents, json_data, champ_dict)
    add_sumspell_pick(row_contents, json_data, sumspell_dict)
    add_stats(row_contents, json_data, item_dict)
    add_team(row_contents, json_data)
    add_team_stats(row_contents, json_data)

    #return pd.DataFrame(row_contents, index=[0])
    return row_contents

# %%
#add on to players1list.txt
#get_many_matches([], api_key, 'players1list.txt', add_on=True)

# %% [markdown]
# ### Defining some helper functions to clean data for create_row()

# %%
#Function to create player#:player name
def add_player_name(to_dict, json_data):
    for player in range(len(json_data.get('participantIdentities'))):
        to_dict['p'+str(player+1)+'_name'] = json_data['participantIdentities'][player]['player'].get('summonerName', 'unknown')
    print(json_data['gameId'])

# %%
#adds champion name
def add_champ_pick(to_dict, json_data, champ_map):
    for player in range(len(json_data['participantIdentities'])):
        champ = json_data['participants'][player].get('championId', 'unknown')
        to_dict['p'+str(player+1)+'_champ'] = champ
        if champ in champ_map:
            to_dict['p'+str(player+1)+'_champ'] = champ_map[to_dict['p'+str(player+1)+'_champ']]

# %%
#addes picks of summoner spells
def add_sumspell_pick(to_dict, json_data, spell_map):
    for player in range(len(json_data['participantIdentities'])):
        spell1 = json_data['participants'][player].get('spell1Id', 'unknown')
        spell2 = json_data['participants'][player].get('spell2Id', 'unknown')
        to_dict['p'+str(player+1)+'_spell1'] = spell1
        to_dict['p'+str(player+1)+'_spell2'] = spell2
        if spell1 in sumspell_dict:
            to_dict['p'+str(player+1)+'_spell1'] = sumspell_dict[to_dict['p'+str(player+1)+'_spell1']]
        if spell2 in sumspell_dict:
            to_dict['p'+str(player+1)+'_spell2'] = sumspell_dict[to_dict['p'+str(player+1)+'_spell2']]

# %%
#define function to add stats to Data Frame
def add_stats(to_dict, json_data, item_map):
    pattern = re.compile('item\d')
    for player in range(len(json_data['participants'])):
        for stat in json_data['participants'][player]['stats']:
            stat_name = json_data['participants'][player]['stats'].get(stat, 'unknown')
            to_dict['p'+str(player+1)+stat] = stat_name
            #if item not in item_map it means its not a current active item as of patch
            if (bool(pattern.match(stat)) == True) and (stat_name in item_map):
                to_dict['p'+str(player+1)+stat] = item_map[to_dict['p'+str(player+1)+stat]]

# %%
#determine team
def add_team(to_dict, json_data):
    for player in range(len(json_data.get('participantIdentities'))):
        to_dict['p'+str(player+1)+'_team'] = json_data['participants'][player].get('teamId', 'unknown')
        if to_dict['p'+str(player+1)+'_team'] == 100:
            to_dict['p'+str(player+1)+'_team'] = 'blue'
       
    else:
            to_dict['p'+str(player+1)+'_team'] = 'red'

# %%
#add stats from all 10 players
def add_team_stats(to_dict, json_data):
    for team in range(len(json_data['teams'])):
        if json_data['teams'][team]['teamId'] == 100:
            for stat in json_data['teams'][team]:
                to_dict['blue_team_'+ stat] = json_data['teams'][team].get(stat, 'unknown')
            del to_dict['blue_team_bans']
            del to_dict['blue_team_teamId']
        else:
            for stat in json_data['teams'][team]:
                to_dict['red_team_'+ stat] = json_data['teams'][team].get(stat, 'unknown')
            del to_dict['red_team_bans']
            del to_dict['red_team_teamId']

# %% [markdown]
# ### Putting it all together

# %%
def create_master_data(match_list, region, key, out_name=None, csv=False):
    #Create csv files of about 10,000 games at a time
    '''
    If csv=True, then the function will create a .csv of the match data,
    otherwise return a dataframe
    
    match_list will be the pickled list of match ids using get_many_matches()
    in PlayerMatches directory
    match_list: pickled filed of match ids in PlayerMatches directory
    '''
    match_data = []
    failed_games = []
    loop_count = 0
    
    
    with open('PlayerMatches\\'+ match_list, 'rb') as file:
        matches = pickle.load(file)
        #Uncomment below to test for 200 matches
        #matches = matches[:200]
  
    #Limit this loop to 100 calls every 2 mins   
    for match in matches:
        try:
            if loop_count == 100:
                print("wait 2 minutes before next call")
                time.sleep(121)
                loop_count = 0

            loop_count += 1
            stats = get_match_stats(match, region, key)

            if stats == None:
                print('Skipping Game...')
                continue

            row = create_row(stats)
            match_data.append(row)
        except Exception as e:
            print(e)
            print('Failed to get data for game: ' + str(match))
            failed_games.append(match)
            continue
            
        
    if csv == False:
        return pd.DataFrame(match_data)

    elif csv == True:
        out_file = 'PlayerMatches\\' + str(out_name) + '.csv'
        x = pd.DataFrame(match_data)
        x.to_csv(out_file)
        
        with open('PlayerMatches\\'+ 'failedgames.txt', 'wb') as file:
            pickle.dump(failed_games, file)
        
    #handle exception if there is an error and write current data to file
    #and print out last match id so I can start back from there

# %%
create_master_data('matchid_2.txt', 'na1', api_key, out_name='match_data_2', csv=True)
# Out:
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2823594331
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2823575444
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2823551721
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2823527139
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2823508664
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2823512188
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2823487973
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2823475612
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2823481043
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2823448086
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2823454578
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2823443001
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2823212375
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2823186195
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2823095153
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2822998590
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2822991115
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2822845776
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2822769388
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2822774007
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2822750922
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2822702739
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2822657697
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2822625158
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2822611098
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2822587138
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2822599945
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2822555489
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2822292727
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2822277824
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,36:120
# 200
# 2822270998
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,37:120
# 200
# 2822192750
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2822184932
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2822145406
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,41:120
# 200
# 2822111423
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,42:120
# 200
# 2822084356
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2822043103
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2822036111
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,46:120
# 200
# 2822009542
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,47:120
# 200
# 2822001966
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2821977291
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2821963638
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2821928419
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2821935927
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2821922719
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2821413253
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2821408219
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2821392676
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2821365935
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2821350324
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2821325486
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2821341365
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2821298984
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2821315803
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2821051030
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2821016680
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2821000259
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2820962123
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2820911758
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2820826521
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2820781990
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2820707974
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2820702829
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2820648166
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2820633237
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2820517337
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2820485628
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2820522121
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2820448736
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2820242525
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2820210935
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2820172928
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,36:120
# 200
# 2820150846
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,37:120
# 200
# 2820133605
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2820105118
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2820100103
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,40:120
# 200
# 2820063556
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,42:120
# 200
# 2820039780
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,43:120
# 200
# 2819906495
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2819901036
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2819894021
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,46:120
# 200
# 2819880098
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2819843828
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,50:120
# 200
# 2819827494
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,51:120
# 200
# 2819816310
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,52:120
# 200
# 2819540411
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,53:120
# 200
# 2819532368
# wait 2 minutes before next call
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2819317015
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2819309785
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2819296034
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2819281753
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2819255747
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2819261230
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2819228163
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2819235307
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2819222937
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2819041043
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2818998617
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2818959542
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2818927278
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2818885830
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2818875048
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2818665227
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2818641426
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2818616381
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2818588266
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2818603910
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2818558184
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2818234011
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2818165557
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2818139936
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2817995888
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2817679626
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2817682253
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2817653011
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2817619576
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2817636798
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2817615192
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,36:120
# 200
# 2817318047
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,37:120
# 200
# 2817298419
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2817059466
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2817051020
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,40:120
# 200
# 2817025802
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,41:120
# 200
# 2816998657
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,43:120
# 200
# 2816959213
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2816972380
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2816929506
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,46:120
# 200
# 2816945089
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,47:120
# 200
# 2816923558
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2816921578
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,49:120
# 200
# 2816673913
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,50:120
# 200
# 2816642764
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,51:120
# 200
# 2816605697
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,52:120
# 200
# 2816590419
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,53:120
# 200
# 2816562423
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,54:120
# 200
# 2816381515
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,55:120
# 200
# 2816363265
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,56:120
# 200
# 2816325056
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,57:120
# 200
# 2816293475
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,58:120
# 200
# 2816277772
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,59:120
# 200
# 2816264161
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,60:120
# 200
# 2816259583
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,61:120
# 200
# 2816238148
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,62:120
# 200
# 2816254432
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,63:120
# 200
# 2815726190
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,64:120
# 200
# 2815295083
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,65:120
# 200
# 2815310415
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,66:120
# 200
# 2815267955
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,67:120
# 200
# 2815284859
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,68:120
# 200
# 2815263303
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,69:120
# 200
# 2814587494
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,70:120
# 200
# 2814590690
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,71:120
# 200
# 2814548118
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2814517595
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2813829343
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2813825418
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2813822348
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2813659402
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2813657260
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2813655491
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2813704078
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2813321864
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2813213067
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2813106443
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2812968552
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2812781216
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2812767317
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2812763156
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2812749676
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2812727305
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2812735314
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2812742111
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2812578998
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2812567702
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2812459651
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2812301788
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2812276350
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2812272375
# 404
# No game data returned
# Skipping Game...
# wait 2 minutes before next call
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2812266744
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2811929340
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2811932286
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2811014533
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2810979177
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2810983273
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2810990715
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2810946888
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2810823179
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2810803845
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2810237254
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2810219038
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2810202770
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2810175380
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2810161361
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2810137551
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2810130361
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2810124721
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2810058082
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2810053764
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2810040046
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2810006567
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2810013239
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2809959481
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2809918591
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2809954652
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2809680435
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2809634720
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2809611131
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,36:120
# 200
# 2809594018
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,37:120
# 200
# 2809577086
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2809560017
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2809532933
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,41:120
# 200
# 2809491062
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,42:120
# 200
# 2809472034
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,43:120
# 200
# 2809443334
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2809426711
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2809352360
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,47:120
# 200
# 2809322644
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2809285917
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,49:120
# 200
# 2809281697
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,50:120
# 200
# 2809275736
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,52:120
# 200
# 2809270454
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,55:120
# 200
# 2808957573
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,56:120
# 200
# 2808937241
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,57:120
# 200
# 2808637476
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,58:120
# 200
# 2808630769
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,60:120
# 200
# 2808566460
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,61:120
# 200
# 2808549655
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,62:120
# 200
# 2808534068
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,63:120
# 200
# 2808506531
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,64:120
# 200
# 2808431825
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,65:120
# 200
# 2808397067
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,66:120
# 200
# 2808390784
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,67:120
# 200
# 2808365800
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,69:120
# 200
# 2808165911
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2808181683
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2807949517
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2807936725
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2807944287
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2807923673
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2807638234
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2807631576
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2807604468
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2807410709
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2807387741
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2807386265
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2806899731
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2806887604
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2800612052
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2800609250
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2800606981
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2800604841
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2800583976
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2800582402
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2800569298
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2800328031
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2800110946
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2800096345
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2800081048
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2800065988
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2800062253
# wait 2 minutes before next call
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2800041567
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2799208305
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2798628840
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2798636281
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2798635039
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2798642842
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2797732734
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2797719966
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2797706186
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2797694453
# 504
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2797690287
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2797668525
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2797676070
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2797007226
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2797000743
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2796969266
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2796986872
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2796984753
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2796091847
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2796078503
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2796057123
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2796064339
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2796071587
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2796059862
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2796048478
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2796026973
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2796044980
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2796033974
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2796042694
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2795286236
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2795081913
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2795280683
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,40:120
# 200
# 2794579182
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,41:120
# 200
# 2794586218
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,42:120
# 200
# 2794573586
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,43:120
# 200
# 2794571578
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2794549291
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2794556926
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,46:120
# 200
# 2794546237
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,47:120
# 200
# 2794564167
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2794553866
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,50:120
# 200
# 2793239565
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,51:120
# 200
# 2793216088
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,52:120
# 200
# 2793213017
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,53:120
# 200
# 2793208670
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,54:120
# 200
# 2793187640
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,55:120
# 200
# 2793195598
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,56:120
# 200
# 2793204126
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,57:120
# 200
# 2793193124
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,58:120
# 200
# 2792325833
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,59:120
# 200
# 2792311211
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,60:120
# 200
# 2792285640
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,61:120
# 200
# 2792281500
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,62:120
# 200
# 2792257232
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,63:120
# 200
# 2792253966
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,64:120
# 200
# 2792251257
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,65:120
# 200
# 2792248466
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2792228038
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2791401423
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2791359200
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2791366142
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2791346047
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2791352810
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2790560959
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2790546873
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2790535792
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2790534042
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2790540950
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2790530214
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2790508802
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2790526491
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2790515652
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2790033908
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2790022915
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2790041647
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2789270043
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2789108013
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2788926276
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2789104394
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2789102753
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2788921903
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2788453461
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2788441392
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2788428353
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2788425983
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2788434433
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2788422466
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2788431255
# wait 2 minutes before next call
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2788410445
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2787878008
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2787877347
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2787865791
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2787863093
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2787881263
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2787759732
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2787758612
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2787756634
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2787023128
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2787030316
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2785622596
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2785610618
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2785595987
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2785574900
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2785110745
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2785077064
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2785064265
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2785083139
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2785061959
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2774107792
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2771759559
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2765090519
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2762931741
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2762898902
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,36:120
# 200
# 2762916411
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,37:120
# 200
# 2762906257
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2760949834
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2759705703
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,40:120
# 200
# 2759669531
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,42:120
# 200
# 2759639342
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,43:120
# 200
# 2759645549
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2759641263
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2759586770
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,46:120
# 200
# 2759585004
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,47:120
# 200
# 2759564183
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2759582780
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,49:120
# 200
# 2759552374
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,50:120
# 200
# 2758912038
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,51:120
# 200
# 2758910218
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,52:120
# 200
# 2758907905
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,53:120
# 200
# 2758887168
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,54:120
# 200
# 2757950938
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,55:120
# 200
# 2757938337
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,57:120
# 200
# 2757934441
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,58:120
# 200
# 2757923293
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,59:120
# 200
# 2757931261
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,60:120
# 200
# 2756515063
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,61:120
# 200
# 2756433309
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,62:120
# 200
# 2756431002
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,63:120
# 200
# 2756419690
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,64:120
# 200
# 2756408410
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,67:120
# 200
# 2754887864
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,68:120
# 200
# 2754905783
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2754904363
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2752567056
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2747452974
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2747416938
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2747404041
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2747366449
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2747350308
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2743615787
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2743604846
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2743603487
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2743592849
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2742730309
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2739849163
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2736478264
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2736470359
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2736417532
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2736397333
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2736391722
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2736347971
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2736339193
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2736308013
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2736145571
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2736107825
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2736063384
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2736030067
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2735983688
# wait 2 minutes before next call
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2735465664
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2735480218
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2735374870
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2733698139
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2727315480
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2726635291
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2726623724
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2724461347
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2724385443
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2724354302
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2724304942
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2724277388
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2724258413
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2724015309
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2724003533
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2720721117
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2720720281
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2720245937
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2718424559
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2718373982
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2718361752
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2718336054
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2718296667
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2718257618
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2718061623
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2718046196
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2718033272
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2718040498
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2718009128
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2718014453
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2718013214
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,37:120
# 200
# 2717278770
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2717152955
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2717148559
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,40:120
# 200
# 2717146353
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,41:120
# 200
# 2717124664
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,42:120
# 200
# 2716762482
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,43:120
# 200
# 2716741688
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2716669142
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,46:120
# 200
# 2716423543
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,47:120
# 200
# 2716396671
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2716381854
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,49:120
# 200
# 2716358157
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,50:120
# 200
# 2716364452
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,51:120
# 200
# 2716352152
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,52:120
# 200
# 2716350223
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,53:120
# 200
# 2715344191
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,54:120
# 200
# 2715335763
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,55:120
# 200
# 2715288872
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,56:120
# 200
# 2715303740
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,57:120
# 200
# 2715290325
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,58:120
# 200
# 2715276371
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,59:120
# 200
# 2715264321
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,60:120
# 200
# 2715272196
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,61:120
# 200
# 2710748849
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,63:120
# 200
# 2710750586
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,64:120
# 200
# 2710717353
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,65:120
# 200
# 2710733914
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,66:120
# 200
# 2710731352
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,67:120
# 200
# 2710707712
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,68:120
# 200
# 2709023041
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,69:120
# 200
# 2709029985
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,70:120
# 200
# 2708994673
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2707949673
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2707902616
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2707844766
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2707787046
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2707414925
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2707385648
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2707338427
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2707302767
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2707291350
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2707261772
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2707225130
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2707188471
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2706973492
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2706471099
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2706418325
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2706371412
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2706326648
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2704192841
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2704172167
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2704132750
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2704114311
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2704086411
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2704047676
# wait 2 minutes before next call
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2704050039
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2704030777
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2703991420
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2703302328
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2703266558
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2703246793
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2703214940
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2703177634
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2703170207
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2702769242
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2702741276
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2702720748
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2702679997
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2702636149
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2702604409
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2702576179
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2698495786
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2698448622
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2697784690
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2697780605
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2697758614
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2697756596
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2696181959
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2696157295
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2696163350
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2696151518
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2696148086
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2696145738
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2696144303
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2696142587
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2696122387
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2810399322
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2810382835
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,36:120
# 200
# 2810358878
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2810321424
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2810284954
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,40:120
# 200
# 2780691441
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,41:120
# 200
# 2764933214
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2764804474
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,46:120
# 200
# 2764787165
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,47:120
# 200
# 2764464697
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2762005727
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,49:120
# 200
# 2762000767
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,50:120
# 200
# 2761968068
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,51:120
# 200
# 2761963469
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,52:120
# 200
# 2761934691
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,53:120
# 200
# 2761915323
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,54:120
# 200
# 2761886843
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,55:120
# 200
# 2761849633
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,56:120
# 200
# 2761831269
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,57:120
# 200
# 2761779618
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,58:120
# 200
# 2761759105
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,59:120
# 200
# 2761741741
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,60:120
# 200
# 2761713613
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,61:120
# 200
# 2761686533
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,62:120
# 200
# 2756226339
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,63:120
# 200
# 2756203916
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,64:120
# 200
# 2756181793
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2756155307
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2756121044
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2756070258
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2755176792
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2755138205
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2755128031
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2754473885
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2753569389
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2753559773
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2753528125
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2751099634
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2743367804
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2831562449
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2827797629
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2817646000
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2817662566
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2817619576
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2815277570
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2810518648
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2809256243
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2809271815
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2809248332
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2808774375
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2808768321
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2808745963
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2808754096
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2808762367
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2808759852
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2808463630
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2808064900
# 404
# No game data returned
# Skipping Game...
# wait 2 minutes before next call
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2762265029
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2707109231
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2707114513
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2707091511
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2707086137
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2707026675
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2706292944
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2706267996
# 404
# No game data returned
# Skipping Game...
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2706234782
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2950183503
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2950170646
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2950158055
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2950155791
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2950162888
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2950161463
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2949767524
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2949771950
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2949738671
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2949744185
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2949740774
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2949708088
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2949716205
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2949713363
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2949691093
# 404
# No game data returned
# Skipping Game...
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2949426777
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2948742343
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2948725987
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2948730778
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2948711103
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2948702569
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2948659501
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2948664032
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,36:120
# 200
# 2948660523
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,37:120
# 200
# 2948649923
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2948643761
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2948626152
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,40:120
# 200
# 2948319191
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,41:120
# 200
# 2948303289
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,42:120
# 200
# 2948267638
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,43:120
# 200
# 2948261598
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2948235737
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2948229892
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,46:120
# 200
# 2948221588
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,47:120
# 200
# 2948188792
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,48:120
# 200
# 2948193108
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,49:120
# 200
# 2948181743
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,50:120
# 200
# 2948149664
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,51:120
# 200
# 2948162539
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,52:120
# 200
# 2948152585
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,53:120
# 200
# 2948141325
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,54:120
# 200
# 2947791232
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,55:120
# 200
# 2947770902
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# 2947743774
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,2:120
# 200
# 2947717292
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,3:120
# 200
# 2947702007
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,4:120
# 200
# 2947680543
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,5:120
# 200
# 2947653088
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,6:120
# 200
# 2947627145
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,7:120
# 200
# 2947606184
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,8:120
# 200
# 2947597520
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,9:120
# 200
# 2947592292
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,10:120
# 200
# 2947572890
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,11:120
# 200
# 2947556748
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,12:120
# 200
# 2947553718
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,13:120
# 200
# 2946846649
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,14:120
# 200
# 2946832992
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,15:120
# 200
# 2946786314
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,16:120
# 200
# 2946776230
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,17:120
# 200
# 2946754297
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,18:120
# 200
# 2946733968
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,19:120
# 200
# 2946706685
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,20:120
# 200
# 2946701651
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,21:120
# 200
# 2946669233
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,22:120
# 200
# 2946670208
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,23:120
# 200
# 2946653954
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,24:120
# 200
# 2946243701
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,25:120
# 200
# 2946223691
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,26:120
# 200
# 2946204830
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,27:120
# 200
# 2946183535
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,28:120
# 200
# 2946159031
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,29:120
# 200
# 2946148931
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,30:120
# 200
# 2946142952
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,31:120
# 200
# 2946117961
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,32:120
# 200
# 2946114023
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,33:120
# 200
# 2946101020
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,34:120
# 200
# 2946089863
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,35:120
# 200
# 2946073456
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,36:120
# 200
# 2945697889
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,37:120
# 200
# 2945674588
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,38:120
# 200
# 2945663655
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,39:120
# 200
# 2945650683
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,40:120
# 200
# 2945624215
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,41:120
# 200
# 2945597503
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,42:120
# 200
# 2945584970
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,43:120
# 200
# 2944875587
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,44:120
# 200
# 2944853182
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,45:120
# 200
# 2944826222
# wait 2 minutes before next call

# %%
#save list of ids 10,000 at a time using naming convention matchid_#
#from the total list of ids make sublists of 10,000 ids for create_master_data() 

#DO THIS BY:
    
with open("PlayerMatches\\players1list.txt", "rb") as file:
    big_list = pickle.load(file)

#FIRST 10000 games
with open("PlayerMatches\\matchid_1.txt", "wb") as file:
    sublist = big_list[:10000] 
    pickle.dump(sublist, file)

#NEXT 10000 games
with open("PlayerMatches\\matchid_5.txt", "wb") as file:
    sublist = big_list[40000:50000] 
    pickle.dump(sublist, file)

# %%
#testing 
#API key needs to be updated once expired
match_id = 2932547603
#return account_id
account_id = get_acct_id('YaomiKing', 'na1', api_key)
print(account_id)
#get json data on past 100 matches
history = get_match_history(account_id, 'na1', '420', '11', 0, api_key)
# Out:
# App Rate Limit 20:1,100:120
# App Rate Limit Count 1:1,1:120
# 200
# KUuZNj9ltgE1fRB4kPMyoOQaaVv1pd81wDC373Dw6NXQkA
# App Rate Limit 20:1,100:120
# App Rate Limit Count 2:1,2:120
# 200

# %%
#df = pd.DataFrame(history['matches'])
# Exploring match history as a Pandas DataFrame
#print(df.info())
